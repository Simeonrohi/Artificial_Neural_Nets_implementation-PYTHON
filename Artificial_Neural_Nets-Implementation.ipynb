# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("C:/Users/91918/Downloads/Churn_Modelling.csv")

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age
# 0             1    15634602   Hargrave          619    France  Female   42  \
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember
# 0          2       0.00              1          1               1  \
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
x = dataset.iloc[:, 3:13].values
y = dataset.iloc[:,13].values

# %%
x
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
print(x)
print(y)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]
# [1 0 1 ... 1 1 0]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
p = LabelEncoder()
x[:,2] = p.fit_transform(x[:,2])

# %%
print(x)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]

# %%
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([('ohe', OneHotEncoder(),[1])], remainder = 'passthrough')
x = np.array(ct.fit_transform(x), dtype = np.str_)

# %%
x = x[:,1:]
print(x)
# Out:
# [['1.0' '0.0' '619' ... '1' '1' '101348.88']
#  ['0.0' '1.0' '608' ... '0' '1' '112542.58']
#  ['1.0' '0.0' '502' ... '1' '0' '113931.57']
#  ...
#  ['1.0' '0.0' '709' ... '0' '1' '42085.58']
#  ['0.0' '0.0' '772' ... '1' '0' '92888.52']
#  ['1.0' '0.0' '792' ... '1' '0' '38190.78']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
import pandas as pd
print(x_train)
# Out:
# [[-1.01460667  1.74309049  0.16958176 ...  0.64259497 -1.03227043
#    1.10643166]
#  [-1.01460667 -0.57369368 -2.30455945 ...  0.64259497  0.9687384
#   -0.74866447]
#  [ 0.98560362 -0.57369368 -1.19119591 ...  0.64259497 -1.03227043
#    1.48533467]
#  ...
#  [ 0.98560362 -0.57369368  0.9015152  ...  0.64259497 -1.03227043
#    1.41231994]
#  [-1.01460667  1.74309049 -0.62420521 ...  0.64259497  0.9687384
#    0.84432121]
#  [-1.01460667 -0.57369368 -0.28401079 ...  0.64259497 -1.03227043
#    0.32472465]]

# %%
pd.DataFrame(x_train)
# Out:
#             0         1         2         3         4         5         6
# 0    -1.014607  1.743090  0.169582 -1.091687 -0.464608  0.006661 -1.215717  \
# 1    -1.014607 -0.573694 -2.304559  0.916013  0.301026 -1.377440 -0.006312
# 2     0.985604 -0.573694 -1.191196 -1.091687 -0.943129 -1.031415  0.579935
# 3    -1.014607  1.743090  0.035566  0.916013  0.109617  0.006661  0.473128
# 4    -1.014607  1.743090  2.056114 -1.091687  1.736588  1.044737  0.810193
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995 -1.014607 -0.573694 -0.582970 -1.091687 -0.656016 -0.339364  0.703104
# 7996 -1.014607  1.743090  1.478815 -1.091687 -1.613058 -0.339364  0.613060
# 7997  0.985604 -0.573694  0.901515  0.916013 -0.368904  0.006661  1.361474
# 7998 -1.014607  1.743090 -0.624205 -1.091687 -0.081791  1.390762 -1.215717
# 7999 -1.014607 -0.573694 -0.284011 -1.091687  0.875251 -1.377440  0.511364
#
#             7         8         9         10
# 0     0.809503  0.642595 -1.032270  1.106432
# 1    -0.921591  0.642595  0.968738 -0.748664
# 2    -0.921591  0.642595 -1.032270  1.485335
# 3    -0.921591  0.642595 -1.032270  1.276528
# 4     0.809503  0.642595  0.968738  0.558378
# ...        ...       ...       ...       ...
# 7995  0.809503  0.642595  0.968738  1.091330
# 7996 -0.921591  0.642595  0.968738  0.131760
# 7997  0.809503  0.642595 -1.032270  1.412320
# 7998  0.809503  0.642595  0.968738  0.844321
# 7999 -0.921591  0.642595 -1.032270  0.324725
#
# [8000 rows x 11 columns]

# %%
# !pip install keras
# Out:
# Collecting keras
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      - -------------------------------------- 0.1/1.7 MB 1.1 MB/s eta 0:00:02
#      -- ------------------------------------- 0.1/1.7 MB 1.3 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.2/1.7 MB 1.9 MB/s eta 0:00:01
#      --------- ------------------------------ 0.4/1.7 MB 2.3 MB/s eta 0:00:01
#      ------------ --------------------------- 0.5/1.7 MB 2.3 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.7/1.7 MB 2.6 MB/s eta 0:00:01
#      ------------------- -------------------- 0.8/1.7 MB 2.7 MB/s eta 0:00:01
#      ---------------------- ----------------- 1.0/1.7 MB 2.7 MB/s eta 0:00:01
#      -------------------------- ------------- 1.2/1.7 MB 2.9 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.3/1.7 MB 2.8 MB/s eta 0:00:01
#      --------------------------------- ------ 1.5/1.7 MB 2.8 MB/s eta 0:00:01
#      ------------------------------------ --- 1.6/1.7 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------- 1.7/1.7 MB 2.9 MB/s eta 0:00:00
# Installing collected packages: keras
# Successfully installed keras-2.12.0
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.12.0-cp310-cp310-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Using cached tensorflow_intel-2.12.0-cp310-cp310-win_amd64.whl (272.8 MB)
# Requirement already satisfied: six>=1.12.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.5.0)
# Collecting tensorboard<2.13,>=2.12
#   Using cached tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
# Collecting jax>=0.3.15
#   Using cached jax-0.4.12-py3-none-any.whl
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.54.2-cp310-cp310-win_amd64.whl (4.1 MB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: packaging in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.6.3)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.9.0-cp310-cp310-win_amd64.whl (2.7 MB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.26)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.1)
# Collecting ml-dtypes>=0.1.0
#   Using cached ml_dtypes-0.2.0-cp310-cp310-win_amd64.whl (938 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.3.6)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.20.0-py2.py3-none-any.whl (181 kB)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.1)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: urllib3<2.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.15)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\91918\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Installing collected packages: rsa, pyasn1-modules, opt-einsum, ml-dtypes, markdown, h5py, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.1 gast-0.4.0 google-auth-2.20.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.54.2 h5py-3.9.0 jax-0.4.12 markdown-3.4.3 ml-dtypes-0.2.0 opt-einsum-3.3.0 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.3 tensorflow-2.12.0 tensorflow-intel-2.12.0
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units=6, kernel_initializer="uniform", activation = "relu", input_dim = 11))

# %%
classifier.add(Dense(units=6, kernel_initializer="uniform", activation = "relu"))

# %%
classifier.add(Dense(units=1, kernel_initializer="uniform", activation = "sigmoid"))

# %%
classifier.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
classifier.fit(x_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 4s 3ms/step - loss: 0.5466 - accuracy: 0.7955
# Epoch 2/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.5014 - accuracy: 0.7960
# Epoch 3/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4956 - accuracy: 0.7960
# Epoch 4/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4854 - accuracy: 0.7960
# Epoch 5/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4683 - accuracy: 0.7960
# Epoch 6/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4491 - accuracy: 0.7960
# Epoch 7/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4393 - accuracy: 0.7960
# Epoch 8/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4362 - accuracy: 0.7960
# Epoch 9/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4345 - accuracy: 0.7960
# Epoch 10/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4332 - accuracy: 0.7960
# Epoch 11/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4323 - accuracy: 0.7960
# Epoch 12/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4313 - accuracy: 0.7960
# Epoch 13/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4304 - accuracy: 0.7960
# Epoch 14/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4283 - accuracy: 0.7960
# Epoch 15/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4240 - accuracy: 0.8002
# Epoch 16/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4187 - accuracy: 0.8165
# Epoch 17/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4159 - accuracy: 0.8242
# Epoch 18/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4133 - accuracy: 0.8242
# Epoch 19/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4109 - accuracy: 0.8299
# Epoch 20/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4101 - accuracy: 0.8291
# Epoch 21/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4090 - accuracy: 0.8306
# Epoch 22/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4077 - accuracy: 0.8307
# Epoch 23/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4069 - accuracy: 0.8299
# Epoch 24/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4068 - accuracy: 0.8314
# Epoch 25/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4056 - accuracy: 0.8303
# Epoch 26/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4055 - accuracy: 0.8326
# Epoch 27/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4047 - accuracy: 0.8326
# Epoch 28/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4049 - accuracy: 0.8325
# Epoch 29/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4044 - accuracy: 0.8314
# Epoch 30/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4041 - accuracy: 0.8326
# Epoch 31/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4037 - accuracy: 0.8345
# Epoch 32/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4038 - accuracy: 0.8334
# Epoch 33/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4036 - accuracy: 0.8345
# Epoch 34/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4030 - accuracy: 0.8324
# Epoch 35/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4025 - accuracy: 0.8339
# Epoch 36/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4025 - accuracy: 0.8326
# Epoch 37/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4019 - accuracy: 0.8332
# Epoch 38/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4019 - accuracy: 0.8335
# Epoch 39/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4018 - accuracy: 0.8345
# Epoch 40/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4010 - accuracy: 0.8329
# Epoch 41/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4015 - accuracy: 0.8349
# Epoch 42/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4013 - accuracy: 0.8349
# Epoch 43/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4011 - accuracy: 0.8340
# Epoch 44/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4008 - accuracy: 0.8341
# Epoch 45/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4003 - accuracy: 0.8338
# Epoch 46/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4007 - accuracy: 0.8345
# Epoch 47/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4005 - accuracy: 0.8341
# Epoch 48/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4002 - accuracy: 0.8346
# Epoch 49/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4001 - accuracy: 0.8338
# Epoch 50/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3994 - accuracy: 0.8359
# Epoch 51/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4000 - accuracy: 0.8359
# Epoch 52/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3997 - accuracy: 0.8361
# Epoch 53/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3996 - accuracy: 0.8342
# Epoch 54/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3992 - accuracy: 0.8313
# Epoch 55/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3993 - accuracy: 0.8347
# Epoch 56/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3992 - accuracy: 0.8345
# Epoch 57/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3993 - accuracy: 0.8353
# Epoch 58/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3992 - accuracy: 0.8339
# Epoch 59/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3992 - accuracy: 0.8340
# Epoch 60/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3987 - accuracy: 0.8350
# Epoch 61/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3989 - accuracy: 0.8357
# Epoch 62/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3988 - accuracy: 0.8353
# Epoch 63/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3984 - accuracy: 0.8356
# Epoch 64/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3982 - accuracy: 0.8366
# Epoch 65/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3978 - accuracy: 0.8354
# Epoch 66/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3981 - accuracy: 0.8342
# Epoch 67/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3983 - accuracy: 0.8356
# Epoch 68/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3982 - accuracy: 0.8347
# Epoch 69/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3982 - accuracy: 0.8342
# Epoch 70/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3976 - accuracy: 0.8359
# Epoch 71/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3971 - accuracy: 0.8341
# Epoch 72/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3976 - accuracy: 0.8359
# Epoch 73/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3979 - accuracy: 0.8349
# Epoch 74/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3973 - accuracy: 0.8359
# Epoch 75/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3976 - accuracy: 0.8378
# Epoch 76/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3977 - accuracy: 0.8334
# Epoch 77/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3972 - accuracy: 0.8366
# Epoch 78/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3970 - accuracy: 0.8366
# Epoch 79/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3970 - accuracy: 0.8374
# Epoch 80/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3973 - accuracy: 0.8359
# Epoch 81/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3969 - accuracy: 0.8366
# Epoch 82/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3970 - accuracy: 0.8382
# Epoch 83/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3965 - accuracy: 0.8375
# Epoch 84/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3969 - accuracy: 0.8365
# Epoch 85/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3963 - accuracy: 0.8360
# Epoch 86/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3964 - accuracy: 0.8369
# Epoch 87/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3972 - accuracy: 0.8359
# Epoch 88/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3960 - accuracy: 0.8364
# Epoch 89/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3962 - accuracy: 0.8380
# Epoch 90/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3958 - accuracy: 0.8351
# Epoch 91/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3966 - accuracy: 0.8371
# Epoch 92/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3963 - accuracy: 0.8374
# Epoch 93/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3956 - accuracy: 0.8379
# Epoch 94/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3962 - accuracy: 0.8353
# Epoch 95/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3957 - accuracy: 0.8346
# Epoch 96/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3959 - accuracy: 0.8371
# Epoch 97/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3950 - accuracy: 0.8372
# Epoch 98/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3958 - accuracy: 0.8354
# Epoch 99/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3956 - accuracy: 0.8396
# Epoch 100/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3951 - accuracy: 0.8378

# %%
y_pred = classifier.predict(x_test)
y_pred = (y_pred>0.5)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
print(y_pred)
# Out:
# [[ True  True False  True  True  True]
#  [ True False False False False False]
#  [ True  True  True  True  True  True]
#  ...
#  [ True  True False  True  True  True]
#  [ True  True  True  True  True  True]
#  [ True  True False  True  True  True]]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)

# %%
print(cm)
# Out:
# [[1538   57]
#  [ 258  147]]

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8425
